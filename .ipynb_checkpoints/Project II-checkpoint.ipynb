# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Importing Datasets

# %%
matches = pd.read_csv('matches.csv')
players = pd.read_csv('Players.csv')
indianPlayers = pd.read_csv("Indian Players.csv")
indianPlayersWithRuns = pd.read_csv("Indian Players with runs and strikerate.csv")
foreignPlayers = pd.read_csv('Foreign Playes.csv')
foreignPlayersWithRuns = pd.read_csv('Foreign Playes with runs and strikerate.csv')

# %% [markdown]
# # Preprocessing of datasets

# %%
indianPlayersWithRuns.dropna(inplace=True)

# %%
foreignPlayersWithRuns.dropna(inplace=True)

# %%
matches
# Out:
#         id    Season           city                 Date  \
# 0       60  IPL-2008      Bangalore  2008-04-18 00:00:00
# 1       70  IPL-2008      Bangalore  2008-04-26 00:00:00
# 2       74  IPL-2008      Bangalore  2008-04-28 00:00:00
# 3      111  IPL-2008      Bangalore  2008-05-03 00:00:00
# 4       84  IPL-2008      Bangalore  2008-05-05 00:00:00
# ..     ...       ...            ...                  ...
# 740  11322  IPL-2019         Mumbai  2019-04-15 00:00:00
# 741  11342  IPL-2019         Mumbai  2019-05-02 00:00:00
# 742  11347  IPL-2019         Mumbai  2019-05-05 00:00:00
# 743  11413  IPL-2019  Visakhapatnam  2019-05-08 00:00:00
# 744  11414  IPL-2019  Visakhapatnam  2019-05-10 00:00:00
#
#                            team1                        team2  \
# 0          Kolkata Knight Riders  Royal Challengers Bangalore
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2            Chennai Super Kings  Royal Challengers Bangalore
# 3    Royal Challengers Bangalore              Deccan Chargers
# 4    Royal Challengers Bangalore              Kings XI Punjab
# ..                           ...                          ...
# 740  Royal Challengers Bangalore               Mumbai Indians
# 741               Mumbai Indians          Sunrisers Hyderabad
# 742        Kolkata Knight Riders               Mumbai Indians
# 743          Sunrisers Hyderabad               Delhi Capitals
# 744               Delhi Capitals          Chennai Super Kings
#
#                      toss_winner toss_decision  result  dl_applied  \
# 0    Royal Challengers Bangalore         field  normal           0
# 1               Rajasthan Royals         field  normal           0
# 2            Chennai Super Kings           bat  normal           0
# 3                Deccan Chargers         field  normal           0
# 4                Kings XI Punjab         field  normal           0
# ..                           ...           ...     ...         ...
# 740               Mumbai Indians         field  normal           0
# 741               Mumbai Indians           bat     tie           0
# 742               Mumbai Indians         field  normal           0
# 743               Delhi Capitals         field  normal           0
# 744          Chennai Super Kings         field  normal           0
#
#                           winner  win_by_runs  win_by_wickets player_of_match  \
# 0          Kolkata Knight Riders          140               0     BB McCullum
# 1               Rajasthan Royals            0               7       SR Watson
# 2            Chennai Super Kings           13               0        MS Dhoni
# 3    Royal Challengers Bangalore            3               0         P Kumar
# 4                Kings XI Punjab            0               6     S Sreesanth
# ..                           ...          ...             ...             ...
# 740               Mumbai Indians            0               5      SL Malinga
# 741               Mumbai Indians            0               0       JJ Bumrah
# 742               Mumbai Indians            0               9       HH Pandya
# 743               Delhi Capitals            0               2         RR Pant
# 744          Chennai Super Kings            0               6    F du Plessis
#
#      Team_win_id                  venue         umpire1         umpire2  \
# 0            8.0  M Chinnaswamy Stadium       Asad Rauf     RE Koertzen
# 1           11.0  M Chinnaswamy Stadium       MR Benson       IL Howell
# 2            1.0  M Chinnaswamy Stadium     BR Doctrove       RB Tiffin
# 3           13.0  M Chinnaswamy Stadium     BR Doctrove      SL Shastri
# 4            6.0  M Chinnaswamy Stadium        SJ Davis     BR Doctrove
# ..           ...                    ...             ...             ...
# 740          9.0       Wankhede Stadium  Marais Erasmus     Nitin Menon
# 741          9.0       Wankhede Stadium          S Ravi        O Nandan
# 742          9.0       Wankhede Stadium   Nanda Kishore        O Nandan
# 743          3.0       ACA-VDCA Stadium             NaN             NaN
# 744          1.0       ACA-VDCA Stadium   Sundaram Ravi  Bruce Oxenford
#
#                      umpire3
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 740            Nanda Kishore
# 741            Nanda Kishore
# 742                   S Ravi
# 743                      NaN
# 744  Chettithody Shamshuddin
#
# [745 rows x 19 columns]

# %%
matches.drop("umpire3",axis=1,inplace=True)

# %%
matches.dropna(inplace=True)

# %%
matches
# Out:
#         id    Season           city                 Date  \
# 0       60  IPL-2008      Bangalore  2008-04-18 00:00:00
# 1       70  IPL-2008      Bangalore  2008-04-26 00:00:00
# 2       74  IPL-2008      Bangalore  2008-04-28 00:00:00
# 3      111  IPL-2008      Bangalore  2008-05-03 00:00:00
# 4       84  IPL-2008      Bangalore  2008-05-05 00:00:00
# ..     ...       ...            ...                  ...
# 739  11318  IPL-2019         Mumbai  2019-04-13 00:00:00
# 740  11322  IPL-2019         Mumbai  2019-04-15 00:00:00
# 741  11342  IPL-2019         Mumbai  2019-05-02 00:00:00
# 742  11347  IPL-2019         Mumbai  2019-05-05 00:00:00
# 744  11414  IPL-2019  Visakhapatnam  2019-05-10 00:00:00
#
#                            team1                        team2  \
# 0          Kolkata Knight Riders  Royal Challengers Bangalore
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2            Chennai Super Kings  Royal Challengers Bangalore
# 3    Royal Challengers Bangalore              Deccan Chargers
# 4    Royal Challengers Bangalore              Kings XI Punjab
# ..                           ...                          ...
# 739               Mumbai Indians             Rajasthan Royals
# 740  Royal Challengers Bangalore               Mumbai Indians
# 741               Mumbai Indians          Sunrisers Hyderabad
# 742        Kolkata Knight Riders               Mumbai Indians
# 744               Delhi Capitals          Chennai Super Kings
#
#                      toss_winner toss_decision  result  dl_applied  \
# 0    Royal Challengers Bangalore         field  normal           0
# 1               Rajasthan Royals         field  normal           0
# 2            Chennai Super Kings           bat  normal           0
# 3                Deccan Chargers         field  normal           0
# 4                Kings XI Punjab         field  normal           0
# ..                           ...           ...     ...         ...
# 739             Rajasthan Royals         field  normal           0
# 740               Mumbai Indians         field  normal           0
# 741               Mumbai Indians           bat     tie           0
# 742               Mumbai Indians         field  normal           0
# 744          Chennai Super Kings         field  normal           0
#
#                           winner  win_by_runs  win_by_wickets player_of_match  \
# 0          Kolkata Knight Riders          140               0     BB McCullum
# 1               Rajasthan Royals            0               7       SR Watson
# 2            Chennai Super Kings           13               0        MS Dhoni
# 3    Royal Challengers Bangalore            3               0         P Kumar
# 4                Kings XI Punjab            0               6     S Sreesanth
# ..                           ...          ...             ...             ...
# 739             Rajasthan Royals            0               4      JC Buttler
# 740               Mumbai Indians            0               5      SL Malinga
# 741               Mumbai Indians            0               0       JJ Bumrah
# 742               Mumbai Indians            0               9       HH Pandya
# 744          Chennai Super Kings            0               6    F du Plessis
#
#      Team_win_id                  venue         umpire1         umpire2
# 0            8.0  M Chinnaswamy Stadium       Asad Rauf     RE Koertzen
# 1           11.0  M Chinnaswamy Stadium       MR Benson       IL Howell
# 2            1.0  M Chinnaswamy Stadium     BR Doctrove       RB Tiffin
# 3           13.0  M Chinnaswamy Stadium     BR Doctrove      SL Shastri
# 4            6.0  M Chinnaswamy Stadium        SJ Davis     BR Doctrove
# ..           ...                    ...             ...             ...
# 739         11.0       Wankhede Stadium     Nitin Menon   Nanda Kishore
# 740          9.0       Wankhede Stadium  Marais Erasmus     Nitin Menon
# 741          9.0       Wankhede Stadium          S Ravi        O Nandan
# 742          9.0       Wankhede Stadium   Nanda Kishore        O Nandan
# 744          1.0       ACA-VDCA Stadium   Sundaram Ravi  Bruce Oxenford
#
# [733 rows x 18 columns]

# %% [markdown]
# # Ploting graphs

# %%
matchWin = matches['winner'].value_counts()
matchWin
# Out:
# Mumbai Indians                 109
# Chennai Super Kings             98
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     82
# Kings XI Punjab                 81
# Rajasthan Royals                75
# Delhi Daredevils                66
# Sunrisers Hyderabad             56
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                   9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
tosswin = matches['toss_winner'].value_counts()  
tosswin
# Out:
# Mumbai Indians                 94
# Kolkata Knight Riders          91
# Chennai Super Kings            89
# Kings XI Punjab                80
# Delhi Daredevils               79
# Rajasthan Royals               77
# Royal Challengers Bangalore    76
# Sunrisers Hyderabad            44
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                  9
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          1
# Name: toss_winner, dtype: int64

# %%
Teams_Of_Win = pd.Series(['Mumbai Indians','Chennai Super Kings','Kolkata Knight Riders','Royal Challengers Bangalore','Kings XI Punjab','Rajasthan Royals','Delhi Daredevils','Sunrisers Hyderabad','Deccan Chargers','Gujarat Lions','Pune Warriors','Delhi Capitals','Kochi Tuskers Kerala','Rising Pune Supergiants'])
count_Of_Win = pd.Series([109,98,92,82,81,75,66,56,29,13,12,9,6,5])

# %%
Teams_Of_Toss = pd.Series(['Mumbai Indians','Kolkata Knight Riders','Chennai Super Kings','Kings XI Punjab','Delhi Daredevils','Rajasthan Royals','Royal Challengers Bangalore','Sunrisers Hyderabad','Deccan Chargers','Pune Warriors','Gujarat Lions','Delhi Capitals','Kochi Tuskers Kerala','Rising Pune Supergiants'])
count_Of_toss = pd.Series([94,91,89,80,79,77,76,44,43,20,15,9,8,8])

# %%
TeamByWin = pd.DataFrame({"Teams":Teams_Of_Win, "No of wins":count_Of_Win})

# %%
TeamByWin
# Out:
#                           Teams  No of wins
# 0                Mumbai Indians         109
# 1           Chennai Super Kings          98
# 2         Kolkata Knight Riders          92
# 3   Royal Challengers Bangalore          82
# 4               Kings XI Punjab          81
# 5              Rajasthan Royals          75
# 6              Delhi Daredevils          66
# 7           Sunrisers Hyderabad          56
# 8               Deccan Chargers          29
# 9                 Gujarat Lions          13
# 10                Pune Warriors          12
# 11               Delhi Capitals           9
# 12         Kochi Tuskers Kerala           6
# 13      Rising Pune Supergiants           5

# %%
TeamByToss = pd.DataFrame({"Teams":Teams_Of_Toss, "No of wins":count_Of_toss})

# %%
TeamByToss
# Out:
#                           Teams  No of wins
# 0                Mumbai Indians          94
# 1         Kolkata Knight Riders          91
# 2           Chennai Super Kings          89
# 3               Kings XI Punjab          80
# 4              Delhi Daredevils          79
# 5              Rajasthan Royals          77
# 6   Royal Challengers Bangalore          76
# 7           Sunrisers Hyderabad          44
# 8               Deccan Chargers          43
# 9                 Pune Warriors          20
# 10                Gujarat Lions          15
# 11               Delhi Capitals           9
# 12         Kochi Tuskers Kerala           8
# 13      Rising Pune Supergiants           8

# %%
TeamByWin.to_csv("Count_of_teams_wins.csv")

# %%
TeamByToss.to_csv("Count_of_teams_wins_by_toss.csv")

# %%
# Count of match winner 
fig,ax=plt.subplots(figsize=(18,8))
ax.barh(TeamByWin['Teams'],TeamByWin['No of wins']);
ax.set(title="Count of match winner",
      xlabel="Wins")
# Out:
# [Text(0.5, 1.0, 'Count of match winner'), Text(0.5, 0, 'Wins')]

# %%
# Count of toss winner
plt.style.use('seaborn-notebook')
TeamByToss.plot(x="Teams", y="No of wins", kind="bar")
# Out:
# <AxesSubplot:xlabel='Teams'>

# %%
matches['toss_decision'].value_counts()
# Out:
# field    445
# bat      288
# Name: toss_decision, dtype: int64

# %%
choice = ['field','bat']
countofchoice = [445,288]

# %%
# Count of choice of batting or field
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
mycolors = ["deepskyblue", "lightblue"]
ax.set_title("Toss decision by toss winner")
ax.pie(countofchoice, labels = choice,autopct='%1.2f%%', shadow=True, colors = mycolors)
plt.show()

# %%
players
# Out:
#         Player_Name                  DOB Batting_Hand           Bowling_Skill  \
# 0    A Ashish Reddy  1991-02-24 00:00:00   Right_Hand        Right-arm medium
# 1        A Chandila  1983-12-05 00:00:00   Right_Hand      Right-arm offbreak
# 2          A Chopra  1977-09-19 00:00:00   Right_Hand      Right-arm offbreak
# 3        A Flintoff  1977-12-06 00:00:00   Right_Hand   Right-arm fast-medium
# 4          A Kumble  1970-10-17 00:00:00   Right_Hand         Legbreak googly
# ..              ...                  ...          ...                     ...
# 466     Younis Khan  1977-11-29 00:00:00   Right_Hand        Right-arm medium
# 467       YS Chahal  1990-07-23 00:00:00   Right_Hand         Legbreak googly
# 468    Yuvraj Singh  1981-12-12 00:00:00    Left_Hand  Slow left-arm orthodox
# 469     YV Takawale  1984-11-05 00:00:00   Right_Hand            Not a Bowler
# 470          Z Khan  1978-10-07 00:00:00   Right_Hand    Left-arm fast-medium
#
#       Country
# 0       India
# 1       India
# 2       India
# 3     England
# 4       India
# ..        ...
# 466  Pakistan
# 467     India
# 468     India
# 469     India
# 470     India
#
# [471 rows x 5 columns]

# %%
players['Batting_Hand'].value_counts()
# Out:
# Right_Hand    348
# Left_Hand     123
# Name: Batting_Hand, dtype: int64

# %%
battingHand = ["Right_Hand","Left_Hand"]
countofbattinghand = [348,123]

# %%
# Count of players batting hand
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
mycolors = ["turquoise", "aliceblue"]
ax.set_title("Count of players batting hand")
ax.pie(countofbattinghand, labels = battingHand,autopct='%1.2f%%', shadow=True, colors = mycolors)
plt.show()

# %%
foreignPlayers['Country'].value_counts()
# Out:
# Australia       72
# South Africa    39
# New Zealand     22
# Sri Lanka       20
# West Indies     19
# England         14
# Pakistan        13
# Bangladesh       5
# Zimbabwea        2
# Netherlands      1
# Name: Country, dtype: int64

# %%
country = ['Australia','South Africa','New Zealand','Sri Lanka','West Indies','England','Pakistan','Bangladesh','Zimbabwea','Netherlands']
countOfCountry = [72,39,22,20,19,14,13,5,2,1]

# %%
# Count of foreign playes by each country
fig,ax=plt.subplots(figsize=(18,8))
ax.plot(country,countOfCountry, color = 'slateblue')
ax.set(title="Foreign players by each country",
      xlabel="Country Names", ylabel="Count")
# Out:
# [Text(0.5, 1.0, 'Foreign players by each country'),
#  Text(0.5, 0, 'Country Names'),
#  Text(0, 0.5, 'Count')]

# %%
indianPlayersWithRuns
# Out:
#         Player_Name  total_runs  strikerate
# 1    A Ashish Reddy       280.0  146.597000
# 2        A Chandila         4.0   57.142899
# 3          A Chopra        53.0   74.647903
# 4          A Kumble        35.0   76.086998
# 5          A Mishra       366.0   95.064903
# ..              ...         ...         ...
# 239       YK Pathan      3222.0  143.839004
# 240       YS Chahal        22.0   45.833302
# 241    Yuvraj Singh      2755.0  129.891998
# 242     YV Takawale       192.0  107.864998
# 243          Z Khan       117.0   84.782600
#
# [234 rows x 3 columns]

# %%
foreignPlayersWithRuns
# Out:
#         Player_Name  total_runs  strikerate
# 1        A Flintoff        62.0  116.981003
# 2         A Symonds       974.0  130.214004
# 3           A Zampa         5.0   62.500000
# 4         AA Noffke         9.0   90.000000
# 5    AB de Villiers      4414.0  152.102005
# ..              ...         ...         ...
# 193        Umar Gul        39.0  205.263000
# 194      UT Khawaja       127.0  127.000000
# 195      WD Parnell        63.0   84.000000
# 196      WPUJC Vaas        81.0  110.959000
# 197     Younis Khan         3.0   42.857101
#
# [189 rows x 3 columns]

# %%
indianplayerstotalrun = indianPlayersWithRuns['total_runs'].sum()
indianplayerstotalrun
# Out:
# 123842.0

# %%
foreignplayerstotalrun = foreignPlayersWithRuns['total_runs'].sum()
foreignplayerstotalrun
# Out:
# 90417.0

# %%
# Comparision between Indian & Foreign players by runs
PlayersCategory = ['Indian', 'Foreign']
Runs = [123842, 90417]
fig,ax=plt.subplots(figsize=(8,4))
ax.scatter(PlayersCategory,Runs, color = 'slateblue')
ax.set(title="Contribution of Indian & Foreign players by runs")
# Out:
# [Text(0.5, 1.0, 'Contribution of Indian & Foreign players by runs')]

# %%
# Strikerate count of Indian players
fig,ax=plt.subplots(figsize=(10,6))
ax.hist(indianPlayersWithRuns['strikerate'], color='cornflowerblue')
ax.set(title="Strikerate of Indian Players")
# Out:
# [Text(0.5, 1.0, 'Strikerate of Indian Players')]

# %%
# Strikerate count of Foreign players
fig,ax=plt.subplots(figsize=(10,6))
ax.hist(foreignPlayersWithRuns['strikerate'], color='darkblue')
ax.set(title="Strikerate of Foreign Players")
# Out:
# [Text(0.5, 1.0, 'Strikerate of Indian Players')]
